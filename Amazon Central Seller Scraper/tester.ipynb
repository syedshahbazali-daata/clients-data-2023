# %%
import os
import time
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By
import undetected_chromedriver as uc

import mysql.connector

# Set database connection parameters
config = {
    'user': 'root',
    'password': 'password',
    'host': 'localhost',
    'port': '3306',
    'database': 'amazonsellerdb'
}

# Connect to the database
try:
    db = mysql.connector.connect(**config)
    print("Connected to database")
except mysql.connector.Error as err:
    print("Failed to connect to database: {}".format(err))
    exit()

# Create a cursor object to execute SQL queries
cursor = db.cursor()


def insert_record(record):
    # Connect to the MySQL database

    # Prepare the SQL query to insert the record
    sql = "INSERT INTO amz_orders (order_id, order_asin, order_item, order_sku, purchase_date, shipping_service, ship_by, deliver_by, ship_to, phone, package_weight, order_sub_total, order_tax) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
    values = tuple(record)

    # Execute the query and commit the changes
    cursor.execute(sql, values)
    db.commit()


def find_element_send_text(ele, text, clear=True):
    while True:
        try:
            input_field = driver.find_element(By.XPATH, ele)
            if clear:
                input_field.clear()
            input_field.send_keys(text)

            break
        except:
            time.sleep(0.1)


def specific_clicker(ele):
    while True:
        try:
            element = driver.find_element(By.XPATH, ele)
            webdriver.ActionChains(driver).move_to_element_with_offset(element, 1, 0).click(element).perform()

            break
        except Exception as e:
            # print(e)
            pass


def specific_clicker2(ele):
    try:
        element = driver.find_element(By.XPATH, ele)
        webdriver.ActionChains(driver).move_to_element_with_offset(element, 1, 0).click(element).perform()

    except Exception as e:
        # print(e)
        pass


def parse_address(address):
    # Split the address string into individual fields
    fields = address.split('\n')
    print(fields)

    # Get the buyer name from the first field
    try:
        buyer_name = fields[0]
    except:
        buyer_name = "NA"

    try:
        st_address = fields[1]
    except:
        st_address = "NA"

    try:
        city = fields[2].split(',')[0]

    except:
        city = "NA"

    try:
        state = fields[2].split(', ')[1].split(' ')[0]
    except:
        state = "NA"

    try:
        zip_code = fields[2].split(', ')[1].split(' ')[-1]
    except:
        zip_code = "NA"

    # Extract the address, city, state, and zip code from the second field

    # Return the parsed address fields as a list
    result = [buyer_name, st_address, city, state, zip_code]
    print(result)
    return result


def close_chrome():
    import os
    try:
        os.system("taskkill /im chrome.exe /f")
    except:
        pass


def get_text(ele):
    while True:
        try:
            element = driver.find_elements(By.XPATH, ele)
            texts = [str(x.text) for x in element][0]
            return texts
        except Exception as e:
            return "NA"


close_chrome()
options = uc.ChromeOptions()
path = os.path.join(os.environ['USERPROFILE'], 'AppData', 'Local', 'Google', 'Chrome', 'User Data')
options.add_argument(fr"user-data-dir={path}")
options.add_argument(f'--profile-directory=Profile 1')
driver = uc.Chrome(options=options)
# Out:
# Connected to database

# %%
# ----> Scraping All Orders Pages
order_pages_url = []
page_no = 1
while True:
    driver.get(f'https://sellercentral.amazon.com/orders-v3?page={page_no}')

    # Wait for the page to load
    while True:
        try:
            driver.find_element(By.XPATH, '//*[@value="Hide Filters"]')
            time.sleep(4)
            driver.find_element(By.XPATH, '//*[@id="myo-table-results-per-page"]/option[@value="100"]').click()
            time.sleep(4)
            break
        except:
            time.sleep(1)

    urls = driver.find_elements(By.XPATH, '//*[@value="Buy shipping"]//ancestor::a')
    if len(urls) == 0:
        break

    urls = [x.get_attribute('href') for x in urls]
    order_pages_url.extend(urls)
    page_no += 1

print(order_pages_url)
print(len(order_pages_url))

for single_order_page in order_pages_url:
    driver.get(single_order_page)
    while True:
        try:
            driver.find_element(By.XPATH, '//*[@data-test-id="order-details-label"]')
            time.sleep(4)
            break
        except:
            time.sleep(1)

    # FIELDS TO SCRAPE: ASIN, ORDER ID, SKU, Purchase date, Shipping service, Ship by, Deliver by, Ship to, Phone, Subtotal, Tax, Total, Order Weight, Brand

    # ASIN
    asins = driver.find_elements(By.XPATH, "//table[@class='a-keyvalue']//span[text()='ASIN']/..")
    asins = list(set([str(x.text).split(":")[1].strip() for x in asins]))

    # ORDER ID
    order_id = get_text('//*[@data-test-id="order-id-value"]')

    # SKU
    skus = driver.find_elements(By.XPATH, "//table[@class='a-keyvalue']//span[text()='SKU']/..")
    skus = list(set([str(x.text).split(":")[1].strip() for x in skus]))

    # Purchase date
    purchase_date = get_text('//*[@data-test-id="order-summary-purchase-date-value"]')

    # Shipping service
    shipping_service = get_text('//*[@data-test-id="order-summary-shipping-service-value"]')

    # Ship by
    ship_by = get_text('//*[@data-test-id="order-summary-shipby-value"]')

    # Deliver by
    deliver_by = get_text('//*[@data-test-id="order-summary-deliverby-value"]')

    # Ship to
    ship_to = get_text('//div[@data-test-id="shipping-section-buyer-address"]')
    order_buyer_name, order_address, order_city, order_state, order_zip_code = parse_address(ship_to)
    ship_to = ship_to.replace("\n", " ")
    print(ship_to)

    # Phone
    phone = get_text('//*[@data-test-id="shipping-section-phone"]')

    # Order Items
    order_items = driver.find_elements(By.XPATH, "//table[@class='a-keyvalue']//*[text()='Order Item ID']/..")
    order_items = list(set([str(x.text).split(":")[1].strip() for x in order_items]))

    # Package Weight
    package_weight = get_text('//*[@name="selected-custom-package"]/..//span[@class="a-dropdown-prompt"]')
    if str(package_weight).lower().strip() == "none":
        package_weight = "NA"

    # Subtotal
    sub_totals = driver.find_elements(By.XPATH,
                                      '//table[@class="a-keyvalue"]//table//*[@class="a-row"]//*[text()="Item subtotal"]//ancestor::div[@class="a-row"]//div[@postion="last"]/span')
    sub_totals = list(set([str(x.text).strip() for x in sub_totals]))
    print(sub_totals)

    # Tax
    taxes = driver.find_elements(By.XPATH,
                                 '//table[@class="a-keyvalue"]//table//*[@class="a-row"]//*[text()="Tax"]//ancestor::div[@class="a-row"]//div[@postion="last"]/span')

    taxes = list(set([str(x.text).strip() for x in taxes]))

    for index, single_order_item in enumerate(asins):
        try:
            order_asin = asins[index]
        except:
            order_asin = "NA"

        try:
            order_item = order_items[index]
        except:
            order_item = "NA"

        try:
            order_sku = skus[index]
        except:
            order_sku = "NA"

        try:
            order_sub_total = sub_totals[index]
        except:
            order_sub_total = "NA"

        try:
            order_tax = taxes[index]
        except:
            order_tax = "NA"

        record = [order_id, order_asin, order_item, order_sku, purchase_date, shipping_service, ship_by, deliver_by,
                  ship_to, phone, package_weight, order_sub_total, order_tax]
        print(record)
        continue
        try:
            insert_record(record)
        except:
            print("Error inserting record")
            print(record)

        print(record)

# Close the cursor and database connection
cursor.close()
db.close()
# Out:
# ['https://sellercentral.amazon.com/orders-v3/order/111-7316153-3501023/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-9403300-1693814/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-9267254-0677035/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-0084335-6385042/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/114-7545067-8696267/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/114-3102222-9993865/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-0943792-3837821/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-9398149-8613067/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-9816945-5346600/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-8014765-1424254/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-5626211-8644253/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/114-6240396-7435463/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-7929446-9702657/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-6801891-3839418/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-2311605-8629854/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-0582057-6604228/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/114-5989089-9235468/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/112-0036770-2096265/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/112-3908481-4477862/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-0184625-7819425/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/112-0779259-2158617/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/114-0156643-5345849/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/112-8323346-7676239/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/114-2227765-8936211/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-8269669-0678619/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-8557797-4885834/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/114-6959145-9048254/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/114-1290559-8124220/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/112-8382637-7006624/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-1622114-4189818/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-2514081-5229008/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-2332180-2402662/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-3538371-9918610/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-8669248-5649821/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-5625924-6454609/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-0109786-3109855/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-7471549-7592261/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-5613732-1102600/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/112-7165968-3335432/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/112-9630513-6788242/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/112-6032408-7109840/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/111-4116139-3046661/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/112-0768812-5917025/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/114-5007242-0719455/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/112-4795573-6615462/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-1910657-1439435/buy-shipping', 'https://sellercentral.amazon.com/orders-v3/order/113-7405708-4245827/buy-shipping', 'htt ...
# 87
# ['kim grasso', '15 BRIDLE TRAIL RD', 'NEEDHAM, MASSACHUSETTS 02492-1478']
# ['kim grasso', '15 BRIDLE TRAIL RD', 'NEEDHAM', 'MASSACHUSETTS', '02492-1478']
# kim grasso 15 BRIDLE TRAIL RD NEEDHAM, MASSACHUSETTS 02492-1478
# ['US$25.98']
# ['111-7316153-3501023', 'B0BY3T1995', '75444408754641', 'OO-4KON-FJAU', 'Thu, Mar 23, 2023, 6:28 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'kim grasso 15 BRIDLE TRAIL RD NEEDHAM, MASSACHUSETTS 02492-1478', '+1 929-436-4790 ext. 40678', 'NA', 'US$25.98', 'US$1.62']
# ['Pam R Thornton', '982 DRIFTWOOD RD', 'TITUS, AL 36080-2848']
# ['Pam R Thornton', '982 DRIFTWOOD RD', 'TITUS', 'AL', '36080-2848']
# Pam R Thornton 982 DRIFTWOOD RD TITUS, AL 36080-2848
# ['US$39.98']
# ['111-9403300-1693814', 'B0BTWJVRZY', '75515931278921', '01-DWFT-Q7EY', 'Fri, Mar 24, 2023, 6:32 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'Pam R Thornton 982 DRIFTWOOD RD TITUS, AL 36080-2848', '+1 314-282-9402 ext. 12855', 'Custom 9 in x 6 in x 3 in', 'US$39.98', 'US$3.20']
# ['Kathleen Fleming', '688 MAIN ST', 'HANOVER, MA 02339-1571']
# ['Kathleen Fleming', '688 MAIN ST', 'HANOVER', 'MA', '02339-1571']
# Kathleen Fleming 688 MAIN ST HANOVER, MA 02339-1571
# ['US$34.98']
# ['111-9267254-0677035', 'B0BTC9NKPH', '75523477289481', '4V-UDT0-HSXL', 'Fri, Mar 24, 2023, 7:17 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'Kathleen Fleming 688 MAIN ST HANOVER, MA 02339-1571', '+1 314-282-9402 ext. 45980', 'Custom 9 in x 6 in x 5 in', 'US$34.98', 'NA']
# ['kristi thebeau holman', '3228 BANGOR DR', 'CHESAPEAKE, VA 23321-4934']
# ['kristi thebeau holman', '3228 BANGOR DR', 'CHESAPEAKE', 'VA', '23321-4934']
# kristi thebeau holman 3228 BANGOR DR CHESAPEAKE, VA 23321-4934
# ['US$34.98']
# ['113-0084335-6385042', 'B0BTC9NKPH', '75513490887441', '4V-UDT0-HSXL', 'Fri, Mar 24, 2023, 7:42 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'kristi thebeau holman 3228 BANGOR DR CHESAPEAKE, VA 23321-4934', '+1 763-225-9463 ext. 81502', 'Custom 9 in x 6 in x 5 in', 'US$34.98', 'US$2.10']
# ['HELENA REDDEKOPP', '1611 CR17', 'Lamesa, TX 79331']
# ['HELENA REDDEKOPP', '1611 CR17', 'Lamesa', 'TX', '79331']
# HELENA REDDEKOPP 1611 CR17 Lamesa, TX 79331
# ['US$34.98']
# ['114-7545067-8696267', 'B0BTC9NKPH', '75521905210721', '4V-UDT0-HSXL', 'Fri, Mar 24, 2023, 8:37 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'HELENA REDDEKOPP 1611 CR17 Lamesa, TX 79331', '+1 210-728-4548 ext. 17720', 'Custom 9 in x 6 in x 5 in', 'US$34.98', 'NA']
# ['thomas b. mcclain', '1212 KINGSBURY DR', 'TYLER, TX 75701-8520']
# ['thomas b. mcclain', '1212 KINGSBURY DR', 'TYLER', 'TX', '75701-8520']
# thomas b. mcclain 1212 KINGSBURY DR TYLER, TX 75701-8520
# ['US$29.98']
# ['114-3102222-9993865', 'B0BM62QT9D', '75525702373001', 'Fancy Leaf-001', 'Fri, Mar 24, 2023, 8:44 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'thomas b. mcclain 1212 KINGSBURY DR TYLER, TX 75701-8520', '+1 480-618-5344 ext. 10095', 'Custom 9 in x 6 in x 4 in', 'US$29.98', 'US$2.47']
# ['Patrick Vala', '8470 NW LAKESIDE DR', 'CARLTON, OR 97111-9414']
# ['Patrick Vala', '8470 NW LAKESIDE DR', 'CARLTON', 'OR', '97111-9414']
# Patrick Vala 8470 NW LAKESIDE DR CARLTON, OR 97111-9414
# ['US$27.98']
# ['113-0943792-3837821', 'B0BM86R85G', '75526246292881', 'Flowers-0027', 'Fri, Mar 24, 2023, 9:39 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'Patrick Vala 8470 NW LAKESIDE DR CARLTON, OR 97111-9414', '+1 480-618-5344 ext. 76529', 'Custom 9 in x 6 in x 3 in', 'US$27.98', 'NA']
# ['Teresa Wenger', '3692 DEW AVE', 'MIDDLETOWN, PA 17057-4664']
# ['Teresa Wenger', '3692 DEW AVE', 'MIDDLETOWN', 'PA', '17057-4664']
# Teresa Wenger 3692 DEW AVE MIDDLETOWN, PA 17057-4664
# ['US$20.98']
# ['111-9398149-8613067', 'B0BTC7L3NM', '75526419439521', 'G7-PVI2-HN19', 'Fri, Mar 24, 2023, 9:39 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'Teresa Wenger 3692 DEW AVE MIDDLETOWN, PA 17057-4664', '+1 347-448-3190 ext. 13678', 'Custom 9 in x 6 in x 3 in', 'US$20.98', 'US$1.26']
# ['Kaye Huddleston', '742 S COLDCREEK RD', 'DADEVILLE, AL 36853-4328']
# ['Kaye Huddleston', '742 S COLDCREEK RD', 'DADEVILLE', 'AL', '36853-4328']
# Kaye Huddleston 742 S COLDCREEK RD DADEVILLE, AL 36853-4328
# ['US$29.98']
# ['113-9816945-5346600', 'B0BT54HZJK', '75526509636721', 'JW-9DEP-Z3OC', 'Fri, Mar 24, 2023, 9:48 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'Kaye Huddleston 742 S COLDCREEK RD DADEVILLE, AL 36853-4328', '+1 929-436-4790 ext. 95965', 'Custom 9 in x 6 in x 5 in', 'US$29.98', 'US$2.40']
# ['MARY ANN NIERENBERG', '30016 JUDSON LN', 'DAGSBORO, DE 19939-3381']
# ['MARY ANN NIERENBERG', '30016 JUDSON LN', 'DAGSBORO', 'DE', '19939-3381']
# MARY ANN NIERENBERG 30016 JUDSON LN DAGSBORO, DE 19939-3381
# ['US$29.98']
# ['113-8014765-1424254', 'B0BSFVXB7J', '75519749093281', '77-8QZ2-FQAV', 'Fri, Mar 24, 2023, 9:57 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'MARY ANN NIERENBERG 30016 JUDSON LN DAGSBORO, DE 19939-3381', '+1 210-728-4548 ext. 14507', 'Custom 10 in x 6 in x 4 in', 'US$29.98', 'NA']
# ['Sabrina Stefan', '3317 KEYS ST', 'ANDERSON, SC 29624-4631']
# ['Sabrina Stefan', '3317 KEYS ST', 'ANDERSON', 'SC', '29624-4631']
# Sabrina Stefan 3317 KEYS ST ANDERSON, SC 29624-4631
# ['US$16.98']
# ['113-5626211-8644253', 'B0BSVJ99TW', '75524360745201', 'JP-IWKI-0C2K', 'Fri, Mar 24, 2023, 10:08 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Thu, Mar 30, 2023', 'Sabrina Stefan 3317 KEYS ST ANDERSON, SC 29624-4631', '+1 347-448-3190 ext. 44105', 'Custom 9 in x 6 in x 3 in', 'US$16.98', 'US$1.19']
# ['michael', '4217 MOCKING BIRD DR', 'BOYNTON BEACH, FL 33436-2635']
# ['michael', '4217 MOCKING BIRD DR', 'BOYNTON BEACH', 'FL', '33436-2635']
# michael 4217 MOCKING BIRD DR BOYNTON BEACH, FL 33436-2635
# ['US$19.98']
# ['114-6240396-7435463', 'B0BSNPJDDP', '75526621964521', 'S6-L41T-0XYN', 'Fri, Mar 24, 2023, 10:09 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'michael 4217 MOCKING BIRD DR BOYNTON BEACH, FL 33436-2635', '+1 347-448-3190 ext. 24323', 'Custom 9 in x 6 in x 4 in', 'US$19.98', 'US$1.40']
# ['Karen', '2007 BAY RIDGE AVE', 'ANNAPOLIS, MD 21403-2826']
# ['Karen', '2007 BAY RIDGE AVE', 'ANNAPOLIS', 'MD', '21403-2826']
# Karen 2007 BAY RIDGE AVE ANNAPOLIS, MD 21403-2826
# ['US$19.98']
# ['111-7929446-9702657', 'B0BSNPJDDP', '75528905363481', 'S6-L41T-0XYN', 'Fri, Mar 24, 2023, 10:10 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'Karen 2007 BAY RIDGE AVE ANNAPOLIS, MD 21403-2826', '+1 314-282-9402 ext. 84826', 'Custom 9 in x 6 in x 4 in', 'US$19.98', 'US$1.20']
# ['Patty Brentz', '155 SUNRISE CV', 'BRANSON, MO 65616-8565']
# ['Patty Brentz', '155 SUNRISE CV', 'BRANSON', 'MO', '65616-8565']
# Patty Brentz 155 SUNRISE CV BRANSON, MO 65616-8565
# ['US$25.98']
# ['111-6801891-3839418', 'B0BNZ7L3X2', '75524441675681', 'Z1-BRCS-SH2M', 'Fri, Mar 24, 2023, 10:27 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'Patty Brentz 155 SUNRISE CV BRANSON, MO 65616-8565', '+1 929-436-4790 ext. 89593', 'Custom 9 in x 6 in x 3 in', 'US$25.98', 'US$1.10']
# ['Glaphre Braswell', '880 YOUNGS LN', 'ROSEBURG, OR 97471-9667']
# ['Glaphre Braswell', '880 YOUNGS LN', 'ROSEBURG', 'OR', '97471-9667']
# Glaphre Braswell 880 YOUNGS LN ROSEBURG, OR 97471-9667
# ['US$18.98']
# ['113-2311605-8629854', 'B0BT9FHTS9', '75517042023961', 'X6-YOIR-X5CO', 'Fri, Mar 24, 2023, 10:28 AM PDT', 'Standard', 'Mon, Mar 27, 2023 to Mon, Mar 27, 2023', 'Wed, Mar 29, 2023 to Fri, Mar 31, 2023', 'Glaphre Braswell 880 YOUNGS LN ROSEBURG, OR 97471-9667', '+1 347-448-3190 ext. 35361', 'Custom 9 in x 6 in x 3 in', 'US$18.98', 'NA']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 30
#      27 print(len(order_pages_url))
#      29 for single_order_page in order_pages_url:
# ---> 30     driver.get(single_order_page)
#      31     while True:
#      32         try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\undetected_chromedriver\__init__.py:645, in Chrome.get(self, url)
#     642 def get(self, url):
#     643     # if self._get_cdc_props():
#     644     #     self._hook_remove_cdc_props()
# --> 645     return super().get(url)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:438, in WebDriver.execute(self, driver_command, params)
#     435     elif "sessionId" not in params:
#     436         params["sessionId"] = self.session_id
# --> 438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
#     440     self.error_handler.check_response(response)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
